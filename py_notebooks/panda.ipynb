# %% [markdown]
# ## 01 - Introduction

# %% [markdown]
# ### Data Frame
# A Data Frame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row and a column.\
# `data_frame = pandas.DataFrame()`

# %%
import pandas as pd

pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.'],
              'Jim': ['Great!', 'So bad.']},
              index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue      Jim
# Product A    I liked it.  Pretty good.   Great!
# Product B  It was awful.        Bland.  So bad.

# %% [markdown]
# ### Series
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. \
# A Series is, in essence, a single column of a DataFrame. So you can assign row labels to the Series the same way as before, using an `index` parameter. However, a Series does not have a column name, it only has one overall `name`.  \
# `series = pandas.Series()`

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], 
          name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ### Importing a Dataset
# So a CSV file is a table of values separated by commas. Hence the name: "Comma-Separated Values", or CSV. \
# We'll use the `pandas.read_csv()` function to read the data into a DataFrame.

# %%
df = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
df
# Out:
#            Gender  Age            Occupation  Sleep Duration  \
# Person ID
# 1            Male   27     Software Engineer             6.1
# 2            Male   28                Doctor             6.2
# 3            Male   28                Doctor             6.2
# 4            Male   28  Sales Representative             5.9
# 5            Male   28  Sales Representative             5.9
# ...           ...  ...                   ...             ...
# 370        Female   59                 Nurse             8.1
# 371        Female   59                 Nurse             8.0
# 372        Female   59                 Nurse             8.1
# 373        Female   59                 Nurse             8.1
# 374        Female   59                 Nurse             8.1
#
#            Quality of Sleep  Physical Activity Level  Stress Level  \
# Person ID
# 1                         6                       42             6
# 2                         6                       60             8
# ...

# %% [markdown]
# ## 02 - Indexing, Selecting & Assigning

# %%
import pandas as pd
df = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)

# %% [markdown]
# ### Indexing
#
# - **Index-based Selection** \
# The first is index-based selection: selecting data based on its numerical position in the data. \
# `yourdataframe.iloc[]`

# %%
df.iloc[0]
# referencing the first row using index 0, all columns
# Out:
# Gender                                  Male
# Age                                       27
# Occupation                 Software Engineer
# Sleep Duration                           6.1
# Quality of Sleep                           6
# Physical Activity Level                   42
# Stress Level                               6
# BMI Category                      Overweight
# Blood Pressure                        126/83
# Heart Rate                                77
# Daily Steps                             4200
# Sleep Disorder                           NaN
# Name: 1, dtype: object

# %% [markdown]
# - **Label-based Selection** \
# The second paradigm for attribute selection is the one followed by the `loc` operator: label-based selection. \
# In this paradigm, it's the data index value, not its position, which matters. \
# `yourdataframe.loc[]`

# %%
df.loc[:, "Occupation"]
# referencing the Occupation column using label selection "Occupation", all rows
# Out:
# Person ID
# 1         Software Engineer
# 2                    Doctor
# 3                    Doctor
# 4      Sales Representative
# 5      Sales Representative
#                ...
# 370                   Nurse
# 371                   Nurse
# 372                   Nurse
# 373                   Nurse
# 374                   Nurse
# Name: Occupation, Length: 374, dtype: str

# %% [markdown]
# - **Manipulating the Index** \
# Label-based selection derives its power from the labels in the index. Critically, the index we use is not immutable. We can manipulate the index in any way we see fit. \
# `yourdataframe.set_index()`

# %%
df.set_index('Occupation', inplace=True)
df
# Out:
#                       Gender  Age  Sleep Duration  Quality of Sleep  \
# Occupation
# Software Engineer       Male   27             6.1                 6
# Doctor                  Male   28             6.2                 6
# Doctor                  Male   28             6.2                 6
# Sales Representative    Male   28             5.9                 4
# Sales Representative    Male   28             5.9                 4
# ...                      ...  ...             ...               ...
# Nurse                 Female   59             8.1                 9
# Nurse                 Female   59             8.0                 9
# Nurse                 Female   59             8.1                 9
# Nurse                 Female   59             8.1                 9
# Nurse                 Female   59             8.1                 9
#
#                       Physical Activity Level  Stress Level BMI Category  \
# Occupation
# ...

# %% [markdown]
# ### Selection

# %%
import pandas as pd

data_source = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
temp = data_source[(data_source["BMI Category"] == "Normal") &
                   (data_source["Occupation"] == "Doctor")]
temp
# Out:
#           Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 2           Male   28     Doctor             6.2                 6
# 3           Male   28     Doctor             6.2                 6
# 8           Male   29     Doctor             7.8                 7
# 9           Male   29     Doctor             7.8                 7
# 10          Male   29     Doctor             7.8                 7
# ...          ...  ...        ...             ...               ...
# 76          Male   33     Doctor             6.0                 6
# 77          Male   33     Doctor             6.0                 6
# 78          Male   33     Doctor             6.0                 6
# 79          Male   33     Doctor             6.0                 6
# 80          Male   33     Doctor             6.0                 6
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# ...

# %%
import pandas as pd

data_source = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
temp = data_source[data_source.Occupation.isin(["Doctor", "Nurse"])]
temp
# Out:
#            Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 2            Male   28     Doctor             6.2                 6
# 3            Male   28     Doctor             6.2                 6
# 8            Male   29     Doctor             7.8                 7
# 9            Male   29     Doctor             7.8                 7
# 10           Male   29     Doctor             7.8                 7
# ...           ...  ...        ...             ...               ...
# 370        Female   59      Nurse             8.1                 9
# 371        Female   59      Nurse             8.0                 9
# 372        Female   59      Nurse             8.1                 9
# 373        Female   59      Nurse             8.1                 9
# 374        Female   59      Nurse             8.1                 9
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# ...

# %%
import pandas as pd

data_source = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
data_source["Occupation"] = "Doctor"
data_source
# Out:
#            Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 1            Male   27     Doctor             6.1                 6
# 2            Male   28     Doctor             6.2                 6
# 3            Male   28     Doctor             6.2                 6
# 4            Male   28     Doctor             5.9                 4
# 5            Male   28     Doctor             5.9                 4
# ...           ...  ...        ...             ...               ...
# 370        Female   59     Doctor             8.1                 9
# 371        Female   59     Doctor             8.0                 9
# 372        Female   59     Doctor             8.1                 9
# 373        Female   59     Doctor             8.1                 9
# 374        Female   59     Doctor             8.1                 9
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# ...

# %% [markdown]
# ## 03 - Summary Functions and Maps

# %%
import pandas as pd

data_source = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
data_source["Heart Rate"].describe()
# Out:
# count    374.000000
# mean      70.165775
# std        4.135676
# min       65.000000
# 25%       68.000000
# 50%       70.000000
# 75%       72.000000
# max       86.000000
# Name: Heart Rate, dtype: float64

# %%
import pandas as pd

data_source = pd.read_csv(r"D:\DS_Crumbs\DS_prep\data\Sleep_health_and_lifestyle_dataset.csv", index_col=0)
data_source["Occupation"].unique()
# Out:
# <StringArray>
# [   'Software Engineer',               'Doctor', 'Sales Representative',
#               'Teacher',                'Nurse',             'Engineer',
#            'Accountant',            'Scientist',               'Lawyer',
#           'Salesperson',              'Manager']
# Length: 11, dtype: str
